# %% [markdown]
# # Data Preparation 4
#
# This notebook consist in the fourth data preparation.
#
# The goal of this notebook is to fill the main Dataframe with selected features in a more automatic way than in the previous notebooks. In particular, is filled the main Dataframe with the admission features corresponding to CATEGORY Labs and Neurological.
#
# The CATEGORY Respiratory, Routine Vital Signs, Skin - Assessment and scores will be left to next notebooks.

# %%
import pandas as pd
from IPython.display import display
import numpy as np
import sqlite3
pd.options.display.max_columns = None
pd.options.display.max_rows = 200

# %%
admissions=pd.read_csv('MAIN_DF_3.csv')
admissions=admissions.drop(['Unnamed: 0'], axis=1)
admissions=admissions.reset_index(drop=True)
print(admissions.shape)
print('unique SUBJECT_ID:', admissions.SUBJECT_ID.nunique())
print('unique HADM_ID   :', admissions.HADM_ID.nunique())
print('unique ICUSTAY_ID:', admissions.ICUSTAY_ID.nunique())
admissions.head()
# Out:
# (51518, 26)
# unique SUBJECT_ID: 37778
# unique HADM_ID   : 48372
# unique ICUSTAY_ID: 51518
#    SUBJECT_ID  HADM_ID  ICUSTAY_ID GENDER  AGE_AD            ADMITTIME  \
# 0           3   145834      211552      M   76.53  2101-10-20 19:08:00
# 1           4   185777      294638      F   47.84  2191-03-16 00:28:00
# 2           6   107064      228232      F   65.94  2175-05-30 07:15:00
# 3           9   150750      220597      M   41.79  2149-11-09 13:06:00
# 4          11   194540      229441      F   50.15  2178-04-16 06:18:00
#
#              DISCHTIME ADMISSION_TYPE INSURANCE ETHNICITY  \
# 0  2101-10-31 13:58:00      EMERGENCY  Medicare     WHITE
# 1  2191-03-23 18:41:00      EMERGENCY   Private     WHITE
# 2  2175-06-15 16:00:00       ELECTIVE  Medicare     WHITE
# 3  2149-11-14 10:15:00      EMERGENCY  Medicaid        NW
# 4  2178-05-11 19:00:00      EMERGENCY   Private     WHITE
#
#                              DIAGNOSIS DBSOURCE FIRST_CAREUNIT  FIRST_WARDID  \
# 0                          HYPOTENSION  carevue           MICU            12
# 1  FEVER,DEHYDRATION,FAILURE TO THRIVE  carevue           MICU            52
# 2            CHRONIC RENAL FAILURE/SDA  carevue           SICU            33
# 3                      HEMORRHAGIC CVA  carevue           MICU            15
# 4                           BRAIN MASS  carevue           SICU            57
#
#                 INTIME              OUTTIME     LOS LOS_C  TIMEDELTA  \
# 0  2101-10-20 19:10:11  2101-10-26 20:43:09  6.0646    >4      10.78
# 1  2191-03-16 00:29:31  2191-03-17 16:46:31  1.6785   1-2       7.76
# 2  2175-05-30 21:30:54  2175-06-03 13:39:54  3.6729   2-4      16.36
# 3  2149-11-09 13:07:02  2149-11-14 20:52:14  5.3231    >4       4.88
# 4  2178-04-16 06:19:32  2178-04-17 20:21:05  1.5844   1-2      25.53
#
#   TIMEDELTA_C  HOSPITAL_EXPIRE_FLAG  HEIGHT  WEIGHT  BMI  I_VEN  NI_VEN
# 0         >10                     0     NaN     NaN  NaN      0       0
# 1        6-10                     0     NaN     NaN  NaN      0       0
# 2         >10                     0     NaN     NaN  NaN      0       0
# 3         3-6                     1     NaN     NaN  NaN      0       0
# 4         >10                     0     NaN     NaN  NaN      0       0

# %%
items=pd.read_excel('ITEMS_ID.xlsx')
items=items.drop(['ROW_ID'], axis=1)
items=items[items['EXTRACT']==1]
print(items.shape)
items=items.reset_index(drop=True)
items
# Out:
# (186, 9)
#      ITEMID                                              LABEL  \
# 0    225792                               Invasive Ventilation
# 1    225794                           Non-invasive Ventilation
# 2    227456                                            Albumin
# 3    225624                                                BUN
# 4    220615                                         Creatinine
# 5    225651                                   Direct Bilirubin
# 6    220621                                    Glucose (serum)
# 7    226537                              Glucose (whole blood)
# 8    228388                       Glucose (whole blood) (soft)
# 9    225664                               Glucose finger stick
# 10   220545                                 Hematocrit (serum)
# 11   226540                    Hematocrit (whole blood - calc)
# 12   225668                                        Lactic Acid
# 13   220235                              Arterial CO2 Pressure
# 14   226062                                Venous CO2 Pressure
# 15   223830                                      PH (Arterial)
# 16   220734                                      PH (dipstick)
# 17   228243                                          PH (SOFT)
# 18   220274                                        PH (Venous)
# 19   227457                                     Platelet Count
# 20   220224                               Arterial O2 pressure
# 21   227516                                 PO2 (Mixed Venous)
# 22   226063                                 Venous O2 Pressure
# 23   220227                             Arterial O2 Saturation
# 24   220645                                     Sodium (serum)
# 25   228389                              Sodium (serum) (soft)
# 26   226534                               Sodium (whole blood)
# 27   228390                        Sodium (whole blood) (soft)
# 28   225690                                    Total Bilirubin
# 29   220546                                                WBC
# 30   220574                                           ZAlbumin
# 31   225678                                    ZPlatelet Count
# 32   220739                                  GCS - Eye Opening
# 33   223901                               GCS - Motor Response
# 34   223900                              GCS - Verbal Response
# 35   223835                               Inspired O2 Fraction
# 36   224688                             Respiratory Rate (Set)
# 37   224689                     Respiratory Rate (spontaneous)
# 38   224690                           Respiratory Rate (Total)
# 39   220210                                   Respiratory Rate
# 40   220277                        O2 saturation pulseoxymetry
# 41   220051                  Arterial Blood Pressure diastolic
# 42   220052                       Arterial Blood Pressure mean
# 43   220050                   Arterial Blood Pressure systolic
# 44   220045                                         Heart Rate
# 45   224643               Manual Blood Pressure Diastolic Left
# 46   227242              Manual Blood Pressure Diastolic Right
# 47   224167                Manual Blood Pressure Systolic Left
# 48   227243               Manual Blood Pressure Systolic Right
# 49   220180              Non Invasive Blood Pressure diastolic
# 50   220181                   Non Invasive Blood Pressure mean
# 51   220179               Non Invasive Blood Pressure systolic
# 52   223762                                Temperature Celsius
# 53   226737                                 AaDO2ApacheIIValue
# 54   226738                                   AgeApacheIIScore
# 55   226739                                   AgeApacheIIValue
# 56   226743                                          APACHE II
# 57   226745                    APACHE II Predecited Death Rate
# 58   226744                           APACHE II PDR - Adjusted
# 59   226746                            ApacheII chronic health
# 60   226747                     APACHEII-Chronic health points
# 61   226748                             APACHEII-Renal failure
# 62   226749                                   ChpApacheIIScore
# 63   226751                            CreatinineApacheIIScore
# 64   226752                            CreatinineApacheIIValue
# 65   226742   APACHE II Diagnosistic weight factors - Surgical
# 66   226741  APACHE II Diagnosistic weight factors - Surgic...
# 67   226740    APACHE II Diagnosistic weight factors - Medical
# 68   226753                                    DswfApacheScore
# 69   226754                                  FiO2ApacheIIValue
# 70   226755                                   GcsApacheIIScore
# 71   226756                                GCSEyeApacheIIValue
# 72   226757                              GCSMotorApacheIIValue
# 73   226758                             GCSVerbalApacheIIValue
# 74   228112                 GCSVerbalApacheIIValue (intubated)
# 75   226759                                  HCO3ApacheIIValue
# 76   226760                                          HCO3Score
# 77   226761                            HematocritApacheIIScore
# 78   226762                            HematocritApacheIIValue
# 79   226763                                    HrApacheIIScore
# 80   226764                                    HrApacheIIValue
# 81   226765                                   MapApacheIIScore
# 82   226766                                   MapApacheIIValue
# 83   226767                                OxygenApacheIIScore
# 84   226768                                    PhApacheIIScore
# 85   226769                                    PHApacheIIValue
# 86   226770                                   PO2ApacheIIValue
# 87   226771                             PotassiumApacheIIScore
# 88   226772                             PotassiumApacheIIValue
# 89   226773                                    RrApacheIIScore
# 90   226774                                    RRApacheIIValue
# 91   226775                                SodiumApacheIIScore
# 92   226776                                SodiumApacheIIValue
# 93   226777                                  TempApacheIIScore
# 94   226778                                  TempApacheIIValue
# 95   226779                                   WbcApacheIIScore
# 96   226780                                   WBCApacheIIValue
# 97   226987                                APACHE IV diagnosis
# 98   226985                       APACHE IV diagnosis choice 1
# 99   226986                       APACHE IV diagnosis choice 2
# 100  226988                APACHE IV main groups non-operative
# 101  226989                    APACHE IV main groups operative
# 102  227025          Non-Operative Cardiovascular (CARDIOVASC)
# 103  227040         Post-Operative Cardiovascular (CARDIOVASC)
# 104  227026                Non-Operative Gastrointestinal (GI)
# 105  227041               Post-Operative Gastrointestinal (GI)
# 106  227027           Non-Operative Genitourinary (GENITOURIN)
# 107  227042          Post-Operative Genitourinary (GENITOURIN)
# 108  227028                  Non-Operative Hematology (HEMATO)
# 109  227043                 Post-Operative Hematology (HEMATO)
# 110  227029     Non-Operative Metabolic/Endocrine (METAB/ENDO)
# 111  227044    Post-Operative Metabolic/Endocrine (METAB/ENDO)
# 112  227030    Non-Operative Musculoskeletal/Skin (MUSKELSKIN)
# 113  227045   Post-Operative Musculoskeletal/Skin (MUSKELSKIN)
# 114  227031              Non-Operative Neurologic (NEUROLOGIC)
# 115  227046             Post-Operative Neurologic (NEUROLOGIC)
# 116  227032               Non-Operative Respiratory (RESPIRAT)
# 117  227047              Post-Operative Respiratory (RESPIRAT)
# 118  227056                               Thrombolytic therapy
# 119  227033              Non-Operative Transplant (TRANSPLANT)
# 120  227048             Post-Operative Transplant (TRANSPLANT)
# 121  227034                      Non-Operative Trauma (TRAUMA)
# 122  227049                     Post-Operative Trauma (TRAUMA)
# 123  227057                                  Type of admission
# 124  227061            Ventilated at any time during ICU Day 1
# 125  226979                                 Admission location
# 126  226980                                  AgeScore_ApacheIV
# 127  226981                                   Albumin_ApacheIV
# 128  226982                              AlbuminScore_ApacheIV
# 129  226983                                   Apache IV A-aDO2
# 130  226984                                      Apache IV Age
# 131  226990                                Apache IV PaFiRatio
# 132  226991                                          APACHEIII
# 133  226993                                       ApacheIV_LOS
# 134  226994                      ApacheIV_Mortality prediction
# 135  226995                           ApacheIV_Natural antilog
# 136  226996                                                APS
# 137  226997                                                ARF
# 138  226998                                 Bilirubin_ApacheIV
# 139  226999                                 BiliScore_ApacheIV
# 140  227000                                       BUN_ApacheIV
# 141  227001                                  BunScore_ApacheIV
# 142  227002                                       CABG Patient
# 143  226750                                   Chronic Dilaysis
# 144  227003                        Chronic health on admission
# 145  227004                              ChronicScore_ApacheIV
# 146  226893                     Coefficient Hospital Mortality
# 147  226894                     Coefficient ICU length of stay
# 148  227005                                Creatinine_ApacheIV
# 149  227006                                CreatScore_ApacheIV
# 150  227007                                           Diabetes
# 151  227008                                  Ejection Fraction
# 152  227010                                      FiO2_ApacheIV
# 153  227009                                  FiO2_ApacheIV_old
# 154  227011                                    GCSEye_ApacheIV
# 155  227012                                  GCSMotor_ApacheIV
# 156  227013                                  GcsScore_ApacheIV
# 157  227014                                 GCSVerbal_ApacheIV
# 158  227015                                   Glucose_ApacheIV
# 159  227016                              GlucoseScore_ApacheIV
# 160  227017                                Hematocrit_ApacheIV
# 161  227018                                        HR_ApacheIV
# 162  227019                                   HrScore_ApacheIV
# 163  227020                                   HtScore_ApacheIV
# 164  227021                                 Intubated_ApacheIV
# 165  227022                              LOS pre-ICU admission
# 166  227023                                       MAP_ApacheIV
# 167  227024                                  MapScore_ApacheIV
# 168  227035                               OxygenScore_ApacheIV
# 169  227036                                      PCO2_ApacheIV
# 170  227037                                        PH_ApacheIV
# 171  227038                              PHPaCO2Score_ApacheIV
# 172  227039                                       PO2_ApacheIV
# 173  228111                                        Readmission
# 174  227050                                        RR_ApacheIV
# 175  227051                                   RRScore_ApacheIV
# 176  227052                                    Sodium_ApacheIV
# 177  227054                              TemperatureF_ApacheIV
# 178  227053                               SodiumScore_ApacheIV
# 179  227055                                 TempScore_ApacheIV
# 180  227519                              Urine output_ApacheIV
# 181  227059                                UrineScore_ApacheIV
# 182  227060                                         Use A-aDO2
# 183  227062                                       WBC_ApacheIV
# 184  227063                                  WBCScore_ApacheIV
# 185  224027                                   Skin Temperature
#
#                                           ABBREVIATION    DBSOURCE  \
# 0                                 Invasive Ventilation  metavision
# 1                             Non-invasive Ventilation  metavision
# 2                                              Albumin  metavision
# 3                                                  BUN  metavision
# 4                                           Creatinine  metavision
# 5                                     Direct Bilirubin  metavision
# 6                                      Glucose (serum)  metavision
# 7                                Glucose (whole blood)  metavision
# 8                         Glucose (whole blood) (soft)  metavision
# 9                                 Glucose finger stick  metavision
# 10                                  Hematocrit (serum)  metavision
# 11                     Hematocrit (whole blood - calc)  metavision
# 12                                         Lactic Acid  metavision
# 13                                     PCO2 (Arterial)  metavision
# 14                                       PCO2 (Venous)  metavision
# 15                                       PH (Arterial)  metavision
# 16                                       PH (dipstick)  metavision
# 17                                           PH (SOFT)  metavision
# 18                                         PH (Venous)  metavision
# 19                                      Platelet Count  metavision
# 20                                      PO2 (Arterial)  metavision
# 21                                  PO2 (Mixed Venous)  metavision
# 22                                        PO2 (Venous)  metavision
# 23                                                SaO2  metavision
# 24                                      Sodium (serum)  metavision
# 25                               Sodium (serum) (soft)  metavision
# 26                                Sodium (whole blood)  metavision
# 27                         Sodium (whole blood) (soft)  metavision
# 28                                     Total Bilirubin  metavision
# 29                                                 WBC  metavision
# 30                                            ZAlbumin  metavision
# 31                                     ZPlatelet Count  metavision
# 32                                         Eye Opening  metavision
# 33                                      Motor Response  metavision
# 34                                     Verbal Response  metavision
# 35                                                FiO2  metavision
# 36                              Respiratory Rate (Set)  metavision
# 37                      Respiratory Rate (spontaneous)  metavision
# 38                            Respiratory Rate (Total)  metavision
# 39                                                  RR  metavision
# 40                                                SpO2  metavision
# 41                                                ABPd  metavision
# 42                                                ABPm  metavision
# 43                                                ABPs  metavision
# 44                                                  HR  metavision
# 45                                        Manual BPd L  metavision
# 46                                        Manual BPd R  metavision
# 47                                        Manual BPs L  metavision
# 48                                        Manual BPs R  metavision
# 49                                                NBPd  metavision
# 50                                                NBPm  metavision
# 51                                                NBPs  metavision
# 52                                       Temperature C  metavision
# 53                                  AaDO2ApacheIIValue  metavision
# 54                                    AgeApacheIIScore  metavision
# 55                                    AgeApacheIIValue  metavision
# 56                                           APACHE II  metavision
# 57                                       APACHE II PDR  metavision
# 58                            APACHE II PDR - Adjusted  metavision
# 59                             ApacheII chronic health  metavision
# 60                                        APACHEII-Chp  metavision
# 61                              APACHEII-Renal failure  metavision
# 62                                    ChpApacheIIScore  metavision
# 63                             CreatinineApacheIIScore  metavision
# 64                             CreatinineApacheIIValue  metavision
# 65           Diagnosistic weight categories - Surgical  metavision
# 66   Diagnosistic weight categories - Surgical emer...  metavision
# 67                Diagnostic weight category - Medical  metavision
# 68                                     DswfApacheScore  metavision
# 69                                   FiO2ApacheIIValue  metavision
# 70                                    GcsApacheIIScore  metavision
# 71                                 GCSEyeApacheIIValue  metavision
# 72                               GCSMotorApacheIIValue  metavision
# 73                              GCSVerbalApacheIIValue  metavision
# 74                  GCSVerbalApacheIIValue (intubated)  metavision
# 75                                   HCO3ApacheIIValue  metavision
# 76                                           HCO3Score  metavision
# 77                             HematocritApacheIIScore  metavision
# 78                             HematocritApacheIIValue  metavision
# 79                                     HrApacheIIScore  metavision
# 80                                     HrApacheIIValue  metavision
# 81                                    MapApacheIIScore  metavision
# 82                                    MapApacheIIValue  metavision
# 83                                 OxygenApacheIIScore  metavision
# 84                                     PhApacheIIScore  metavision
# 85                                     PHApacheIIValue  metavision
# 86                                    PO2ApacheIIValue  metavision
# 87                              PotassiumApacheIIScore  metavision
# 88                              PotassiumApacheIIValue  metavision
# 89                                     RrApacheIIScore  metavision
# 90                                     RRApacheIIValue  metavision
# 91                                 SodiumApacheIIScore  metavision
# 92                                 SodiumApacheIIValue  metavision
# 93                                   TempApacheIIScore  metavision
# 94                                   TempApacheIIValue  metavision
# 95                                    WbcApacheIIScore  metavision
# 96                                    WBCApacheIIValue  metavision
# 97                                 APACHE IV diagnosis  metavision
# 98                        APACHE IV diagnosis choice 1  metavision
# 99                        APACHE IV diagnosis choice 2  metavision
# 100                APACHE IV main group non-operatives  metavision
# 101                     APACHE IV main group operative  metavision
# 102                       Cardiovascular Non-Operative  metavision
# 103                      Cardiovascular Post-Operative  metavision
# 104                     Gastrointestinal Non-Operative  metavision
# 105                    Gastrointestinal Post-Operative  metavision
# 106                        Genitourinary Non-Operative  metavision
# 107                       Genitourinary Post-Operative  metavision
# 108                           Hematology Non-Operative  metavision
# 109                          Hematology Post-Operative  metavision
# 110                  Metabolic/Endocrine Non-Operative  metavision
# 111                 Metabolic/Endocrine Post-Operative  metavision
# 112                 Musculoskeletal/Skin Non-Operative  metavision
# 113                Musculoskeletal/Skin Post-Operative  metavision
# 114                           Neurologic Non-Operative  metavision
# 115                          Neurologic Post-Operative  metavision
# 116                          Respiratory Non-Operative  metavision
# 117                         Respiratory Post-Operative  metavision
# 118                               Thrombolytic therapy  metavision
# 119                           Transplant Non-Operative  metavision
# 120                          Transplant Post-Operative  metavision
# 121                               Trauma Non-Operative  metavision
# 122                              Trauma Post-Operative  metavision
# 123                                  Type of admission  metavision
# 124            Ventilated at any time during ICU Day 1  metavision
# 125                                 Admission location  metavision
# 126                                  AgeScore_ApacheIV  metavision
# 127                                   Albumin_ApacheIV  metavision
# 128                              AlbuminScore_ApacheIV  metavision
# 129                                   Apache IV A-aDO2  metavision
# 130                                      Apache IV Age  metavision
# 131                                Apache IV PaFiRatio  metavision
# 132                                          APACHEIII  metavision
# 133                                       ApacheIV_LOS  metavision
# 134                      ApacheIV_Mortality prediction  metavision
# 135                           ApacheIV_Natural antilog  metavision
# 136                                                APS  metavision
# 137                                                ARF  metavision
# 138                                 Bilirubin_ApacheIV  metavision
# 139                                 BiliScore_ApacheIV  metavision
# 140                                       BUN_ApacheIV  metavision
# 141                                  BunScore_ApacheIV  metavision
# 142                                       CABG Patient  metavision
# 143                                   Chronic Dilaysis  metavision
# 144                        Chronic health on admission  metavision
# 145                              ChronicScore_ApacheIV  metavision
# 146                     Coefficient Hospital Mortality  metavision
# 147                     Coefficient ICU length of stay  metavision
# 148                                Creatinine_ApacheIV  metavision
# 149                                CreatScore_ApacheIV  metavision
# 150                                           Diabetes  metavision
# 151                                  Ejection Fraction  metavision
# 152                                      FiO2_ApacheIV  metavision
# 153                                  FiO2_ApacheIV_old  metavision
# 154                                    GCSEye_ApacheIV  metavision
# 155                                  GCSMotor_ApacheIV  metavision
# 156                                  GcsScore_ApacheIV  metavision
# 157                                 GCSVerbal_ApacheIV  metavision
# 158                                   Glucose_ApacheIV  metavision
# 159                              GlucoseScore_ApacheIV  metavision
# 160                                Hematocrit_ApacheIV  metavision
# 161                                        HR_ApacheIV  metavision
# 162                                   HrScore_ApacheIV  metavision
# 163                                   HtScore_ApacheIV  metavision
# 164                                 Intubated_ApacheIV  metavision
# 165                              LOS pre-ICU admission  metavision
# 166                                       MAP_ApacheIV  metavision
# 167                                  MapScore_ApacheIV  metavision
# 168                               OxygenScore_ApacheIV  metavision
# 169                                      PCO2_ApacheIV  metavision
# 170                                        PH_ApacheIV  metavision
# 171                              PHPaCO2Score_ApacheIV  metavision
# 172                                       PO2_ApacheIV  metavision
# 173                                        Readmission  metavision
# 174                                        RR_ApacheIV  metavision
# 175                                   RRScore_ApacheIV  metavision
# 176                                    Sodium_ApacheIV  metavision
# 177                              TemperatureF_ApacheIV  metavision
# 178                               SodiumScore_ApacheIV  metavision
# 179                                 TempScore_ApacheIV  metavision
# 180                                       Urine output  metavision
# 181                                UrineScore_ApacheIV  metavision
# 182                                         Use A-aDO2  metavision
# 183                                       WBC_ApacheIV  metavision
# 184                                  WBCScore_ApacheIV  metavision
# 185                                          Skin Temp  metavision
#
#                 LINKSTO                CATEGORY  UNITNAME        PARAM_TYPE  \
# 0    procedureevents_mv           2-Ventilation      None           Process
# 1    procedureevents_mv           2-Ventilation      None           Process
# 2           chartevents                    Labs      None  Numeric with tag
# 3           chartevents                    Labs      None           Numeric
# 4           chartevents                    Labs      None           Numeric
# 5           chartevents                    Labs      None           Numeric
# 6           chartevents                    Labs      None           Numeric
# 7           chartevents                    Labs      None           Numeric
# 8           chartevents                    Labs      None  Numeric with tag
# 9           chartevents                    Labs      None           Numeric
# 10          chartevents                    Labs      None           Numeric
# 11          chartevents                    Labs      None           Numeric
# 12          chartevents                    Labs      None           Numeric
# 13          chartevents                    Labs      mmHg           Numeric
# 14          chartevents                    Labs      mmHg           Numeric
# 15          chartevents                    Labs      None           Numeric
# 16          chartevents                    Labs      None           Numeric
# 17          chartevents                    Labs      None           Numeric
# 18          chartevents                    Labs      None           Numeric
# 19          chartevents                    Labs      None  Numeric with tag
# 20          chartevents                    Labs      mmHg           Numeric
# 21          chartevents                    Labs      mmHg           Numeric
# 22          chartevents                    Labs      mmHg           Numeric
# 23          chartevents                    Labs         %           Numeric
# 24          chartevents                    Labs      None           Numeric
# 25          chartevents                    Labs      None  Numeric with tag
# 26          chartevents                    Labs      None           Numeric
# 27          chartevents                    Labs      None  Numeric with tag
# 28          chartevents                    Labs      None           Numeric
# 29          chartevents                    Labs      None           Numeric
# 30          chartevents                    Labs      None           Numeric
# 31          chartevents                    Labs      None           Numeric
# 32          chartevents            Neurological       NaN              Text
# 33          chartevents            Neurological       NaN              Text
# 34          chartevents            Neurological       NaN              Text
# 35          chartevents             Respiratory      None           Numeric
# 36          chartevents             Respiratory  insp/min           Numeric
# 37          chartevents             Respiratory  insp/min           Numeric
# 38          chartevents             Respiratory  insp/min           Numeric
# 39          chartevents             Respiratory  insp/min           Numeric
# 40          chartevents             Respiratory         %           Numeric
# 41          chartevents     Routine Vital Signs      mmHg           Numeric
# 42          chartevents     Routine Vital Signs      mmHg           Numeric
# 43          chartevents     Routine Vital Signs      mmHg           Numeric
# 44          chartevents     Routine Vital Signs       bpm           Numeric
# 45          chartevents     Routine Vital Signs      mmHg           Numeric
# 46          chartevents     Routine Vital Signs      mmHg           Numeric
# 47          chartevents     Routine Vital Signs      mmHg           Numeric
# 48          chartevents     Routine Vital Signs      mmHg           Numeric
# 49          chartevents     Routine Vital Signs      mmHg           Numeric
# 50          chartevents     Routine Vital Signs      mmHg           Numeric
# 51          chartevents     Routine Vital Signs      mmHg           Numeric
# 52          chartevents     Routine Vital Signs        ?C           Numeric
# 53          chartevents      Scores - APACHE II      mmHg           Numeric
# 54          chartevents      Scores - APACHE II      None           Numeric
# 55          chartevents      Scores - APACHE II     years           Numeric
# 56          chartevents      Scores - APACHE II      None           Numeric
# 57          chartevents      Scores - APACHE II         %           Numeric
# 58          chartevents      Scores - APACHE II         %           Numeric
# 59          chartevents      Scores - APACHE II       NaN              Text
# 60          chartevents      Scores - APACHE II       NaN              Text
# 61          chartevents      Scores - APACHE II       NaN          Checkbox
# 62          chartevents      Scores - APACHE II      None           Numeric
# 63          chartevents      Scores - APACHE II      None           Numeric
# 64          chartevents      Scores - APACHE II      None           Numeric
# 65          chartevents      Scores - APACHE II       NaN              Text
# 66          chartevents      Scores - APACHE II       NaN              Text
# 67          chartevents      Scores - APACHE II       NaN              Text
# 68          chartevents      Scores - APACHE II      None           Numeric
# 69          chartevents      Scores - APACHE II         %           Numeric
# 70          chartevents      Scores - APACHE II      None           Numeric
# 71          chartevents      Scores - APACHE II       NaN              Text
# 72          chartevents      Scores - APACHE II       NaN              Text
# 73          chartevents      Scores - APACHE II       NaN              Text
# 74          chartevents      Scores - APACHE II       NaN              Text
# 75          chartevents      Scores - APACHE II      None           Numeric
# 76          chartevents      Scores - APACHE II      None           Numeric
# 77          chartevents      Scores - APACHE II      None           Numeric
# 78          chartevents      Scores - APACHE II      None           Numeric
# 79          chartevents      Scores - APACHE II      None           Numeric
# 80          chartevents      Scores - APACHE II       bpm           Numeric
# 81          chartevents      Scores - APACHE II      None           Numeric
# 82          chartevents      Scores - APACHE II      mmHg           Numeric
# 83          chartevents      Scores - APACHE II      None           Numeric
# 84          chartevents      Scores - APACHE II      None           Numeric
# 85          chartevents      Scores - APACHE II      None           Numeric
# 86          chartevents      Scores - APACHE II      None           Numeric
# 87          chartevents      Scores - APACHE II      None           Numeric
# 88          chartevents      Scores - APACHE II      None           Numeric
# 89          chartevents      Scores - APACHE II      None           Numeric
# 90          chartevents      Scores - APACHE II  insp/min           Numeric
# 91          chartevents      Scores - APACHE II      None           Numeric
# 92          chartevents      Scores - APACHE II      None           Numeric
# 93          chartevents      Scores - APACHE II      None           Numeric
# 94          chartevents      Scores - APACHE II        ?F           Numeric
# 95          chartevents      Scores - APACHE II      None           Numeric
# 96          chartevents      Scores - APACHE II      None           Numeric
# 97          chartevents      Scores - APACHE IV       NaN              Text
# 98          chartevents      Scores - APACHE IV       NaN              Text
# 99          chartevents      Scores - APACHE IV       NaN              Text
# 100         chartevents      Scores - APACHE IV       NaN              Text
# 101         chartevents      Scores - APACHE IV       NaN              Text
# 102         chartevents      Scores - APACHE IV       NaN              Text
# 103         chartevents      Scores - APACHE IV       NaN              Text
# 104         chartevents      Scores - APACHE IV       NaN              Text
# 105         chartevents      Scores - APACHE IV       NaN              Text
# 106         chartevents      Scores - APACHE IV       NaN              Text
# 107         chartevents      Scores - APACHE IV       NaN              Text
# 108         chartevents      Scores - APACHE IV       NaN              Text
# 109         chartevents      Scores - APACHE IV       NaN              Text
# 110         chartevents      Scores - APACHE IV       NaN              Text
# 111         chartevents      Scores - APACHE IV       NaN              Text
# 112         chartevents      Scores - APACHE IV       NaN              Text
# 113         chartevents      Scores - APACHE IV       NaN              Text
# 114         chartevents      Scores - APACHE IV       NaN              Text
# 115         chartevents      Scores - APACHE IV       NaN              Text
# 116         chartevents      Scores - APACHE IV       NaN              Text
# 117         chartevents      Scores - APACHE IV       NaN              Text
# 118         chartevents      Scores - APACHE IV       NaN          Checkbox
# 119         chartevents      Scores - APACHE IV       NaN              Text
# 120         chartevents      Scores - APACHE IV       NaN              Text
# 121         chartevents      Scores - APACHE IV       NaN              Text
# 122         chartevents      Scores - APACHE IV       NaN              Text
# 123         chartevents      Scores - APACHE IV       NaN              Text
# 124         chartevents      Scores - APACHE IV       NaN          Checkbox
# 125         chartevents  Scores - APACHE IV (2)       NaN              Text
# 126         chartevents  Scores - APACHE IV (2)      None           Numeric
# 127         chartevents  Scores - APACHE IV (2)      None           Numeric
# 128         chartevents  Scores - APACHE IV (2)      None           Numeric
# 129         chartevents  Scores - APACHE IV (2)      None           Numeric
# 130         chartevents  Scores - APACHE IV (2)     years           Numeric
# 131         chartevents  Scores - APACHE IV (2)      None           Numeric
# 132         chartevents  Scores - APACHE IV (2)      None           Numeric
# 133         chartevents  Scores - APACHE IV (2)         %           Numeric
# 134         chartevents  Scores - APACHE IV (2)      None           Numeric
# 135         chartevents  Scores - APACHE IV (2)      None           Numeric
# 136         chartevents  Scores - APACHE IV (2)      None           Numeric
# 137         chartevents  Scores - APACHE IV (2)       NaN          Checkbox
# 138         chartevents  Scores - APACHE IV (2)      None           Numeric
# 139         chartevents  Scores - APACHE IV (2)      None           Numeric
# 140         chartevents  Scores - APACHE IV (2)      None           Numeric
# 141         chartevents  Scores - APACHE IV (2)      None           Numeric
# 142         chartevents  Scores - APACHE IV (2)       NaN          Checkbox
# 143         chartevents  Scores - APACHE IV (2)       NaN          Checkbox
# 144         chartevents  Scores - APACHE IV (2)       NaN              Text
# 145         chartevents  Scores - APACHE IV (2)      None           Numeric
# 146         chartevents  Scores - APACHE IV (2)       NaN              Text
# 147         chartevents  Scores - APACHE IV (2)       NaN              Text
# 148         chartevents  Scores - APACHE IV (2)      None           Numeric
# 149         chartevents  Scores - APACHE IV (2)      None           Numeric
# 150         chartevents  Scores - APACHE IV (2)       NaN          Checkbox
# 151         chartevents  Scores - APACHE IV (2)         %           Numeric
# 152         chartevents  Scores - APACHE IV (2)         %           Numeric
# 153         chartevents  Scores - APACHE IV (2)      None           Numeric
# 154         chartevents  Scores - APACHE IV (2)       NaN              Text
# 155         chartevents  Scores - APACHE IV (2)       NaN              Text
# 156         chartevents  Scores - APACHE IV (2)      None           Numeric
# 157         chartevents  Scores - APACHE IV (2)       NaN              Text
# 158         chartevents  Scores - APACHE IV (2)      None           Numeric
# 159         chartevents  Scores - APACHE IV (2)      None           Numeric
# 160         chartevents  Scores - APACHE IV (2)      None           Numeric
# 161         chartevents  Scores - APACHE IV (2)       bpm           Numeric
# 162         chartevents  Scores - APACHE IV (2)      None           Numeric
# 163         chartevents  Scores - APACHE IV (2)      None           Numeric
# 164         chartevents  Scores - APACHE IV (2)       NaN          Checkbox
# 165         chartevents  Scores - APACHE IV (2)      None           Numeric
# 166         chartevents  Scores - APACHE IV (2)      mmHg           Numeric
# 167         chartevents  Scores - APACHE IV (2)      None           Numeric
# 168         chartevents  Scores - APACHE IV (2)      None           Numeric
# 169         chartevents  Scores - APACHE IV (2)      None           Numeric
# 170         chartevents  Scores - APACHE IV (2)      None           Numeric
# 171         chartevents  Scores - APACHE IV (2)      None           Numeric
# 172         chartevents  Scores - APACHE IV (2)      mmHg           Numeric
# 173         chartevents  Scores - APACHE IV (2)       NaN          Checkbox
# 174         chartevents  Scores - APACHE IV (2)  insp/min           Numeric
# 175         chartevents  Scores - APACHE IV (2)      None           Numeric
# 176         chartevents  Scores - APACHE IV (2)      None           Numeric
# 177         chartevents  Scores - APACHE IV (2)        ?F           Numeric
# 178         chartevents  Scores - APACHE IV (2)      None           Numeric
# 179         chartevents  Scores - APACHE IV (2)      None           Numeric
# 180         chartevents  Scores - APACHE IV (2)      None           Numeric
# 181         chartevents  Scores - APACHE IV (2)      None           Numeric
# 182         chartevents  Scores - APACHE IV (2)       NaN          Checkbox
# 183         chartevents  Scores - APACHE IV (2)      None           Numeric
# 184         chartevents  Scores - APACHE IV (2)      None           Numeric
# 185         chartevents       Skin - Assessment       NaN              Text
#
#      EXTRACT
# 0        1.0
# 1        1.0
# 2        1.0
# 3        1.0
# 4        1.0
# 5        1.0
# 6        1.0
# 7        1.0
# 8        1.0
# 9        1.0
# 10       1.0
# 11       1.0
# 12       1.0
# 13       1.0
# 14       1.0
# 15       1.0
# 16       1.0
# 17       1.0
# 18       1.0
# 19       1.0
# 20       1.0
# 21       1.0
# 22       1.0
# 23       1.0
# 24       1.0
# 25       1.0
# 26       1.0
# 27       1.0
# 28       1.0
# 29       1.0
# 30       1.0
# 31       1.0
# 32       1.0
# 33       1.0
# 34       1.0
# 35       1.0
# 36       1.0
# 37       1.0
# 38       1.0
# 39       1.0
# 40       1.0
# 41       1.0
# 42       1.0
# 43       1.0
# 44       1.0
# 45       1.0
# 46       1.0
# 47       1.0
# 48       1.0
# 49       1.0
# 50       1.0
# 51       1.0
# 52       1.0
# 53       1.0
# 54       1.0
# 55       1.0
# 56       1.0
# 57       1.0
# 58       1.0
# 59       1.0
# 60       1.0
# 61       1.0
# 62       1.0
# 63       1.0
# 64       1.0
# 65       1.0
# 66       1.0
# 67       1.0
# 68       1.0
# 69       1.0
# 70       1.0
# 71       1.0
# 72       1.0
# 73       1.0
# 74       1.0
# 75       1.0
# 76       1.0
# 77       1.0
# 78       1.0
# 79       1.0
# 80       1.0
# 81       1.0
# 82       1.0
# 83       1.0
# 84       1.0
# 85       1.0
# 86       1.0
# 87       1.0
# 88       1.0
# 89       1.0
# 90       1.0
# 91       1.0
# 92       1.0
# 93       1.0
# 94       1.0
# 95       1.0
# 96       1.0
# 97       1.0
# 98       1.0
# 99       1.0
# 100      1.0
# 101      1.0
# 102      1.0
# 103      1.0
# 104      1.0
# 105      1.0
# 106      1.0
# 107      1.0
# 108      1.0
# 109      1.0
# 110      1.0
# 111      1.0
# 112      1.0
# 113      1.0
# 114      1.0
# 115      1.0
# 116      1.0
# 117      1.0
# 118      1.0
# 119      1.0
# 120      1.0
# 121      1.0
# 122      1.0
# 123      1.0
# 124      1.0
# 125      1.0
# 126      1.0
# 127      1.0
# 128      1.0
# 129      1.0
# 130      1.0
# 131      1.0
# 132      1.0
# 133      1.0
# 134      1.0
# 135      1.0
# 136      1.0
# 137      1.0
# 138      1.0
# 139      1.0
# 140      1.0
# 141      1.0
# 142      1.0
# 143      1.0
# 144      1.0
# 145      1.0
# 146      1.0
# 147      1.0
# 148      1.0
# 149      1.0
# 150      1.0
# 151      1.0
# 152      1.0
# 153      1.0
# 154      1.0
# 155      1.0
# 156      1.0
# 157      1.0
# 158      1.0
# 159      1.0
# 160      1.0
# 161      1.0
# 162      1.0
# 163      1.0
# 164      1.0
# 165      1.0
# 166      1.0
# 167      1.0
# 168      1.0
# 169      1.0
# 170      1.0
# 171      1.0
# 172      1.0
# 173      1.0
# 174      1.0
# 175      1.0
# 176      1.0
# 177      1.0
# 178      1.0
# 179      1.0
# 180      1.0
# 181      1.0
# 182      1.0
# 183      1.0
# 184      1.0
# 185      1.0

# %% [markdown]
# ## Albumin extraction

# %% [markdown]
# I defined a function to extract the admission values for each feature with the following procedure:
# 1. Takes a database file, a database location, an id and a dataframe (admissions) as arguments
# 2. Construct an SQL instruction to perform a desired query
# 3. Convert the output of the query to a pandas Dataframe
# 4. Drop non informative attributes
# 5. Rename informative attributes in order to carry more meaning
# 6. Take the first measure value for each available feature and for each ICUSTAY_ID
# 7. Merge the resulting dataframe to the original one
# 8. Convert the time of all the available measures in time with respect the admission in the ICU

# %%
database_file = 'CHARTEVENTS_DB'
database_loc  = 'data/CHARTEVENTS.db'
ids = items.ITEMID[2]

# %%
def get_pd(database_file, database_loc, ids, admissions):
    connex = sqlite3.connect(database_loc)
    cur = connex.cursor()
    ids = str(ids)
    str_matching = "(" + ids + ")"
    sql = "SELECT * FROM " + database_file + " WHERE ITEMID IN " + str_matching + ";"
    print('String of SQL:', sql)
    cur.execute(sql)
    df=pd.read_sql_query(sql, connex)
    df=df[df['ERROR']==0]
    df=df.drop(['ROW_ID', 'ITEMID', 'STORETIME', 'CGID', 'VALUENUM', 'WARNING', 
                                'ERROR', 'RESULTSTATUS', 'STOPPED'], axis=1)
    df=df.rename({'CHARTTIME':ids + '_T', 'VALUE':ids + '_V', 'VALUEUOM':ids + '_U'}, axis='columns')
    df=df.sort_values(by=[ids + '_T'])
    df=df.drop_duplicates('ICUSTAY_ID')
    admissions=pd.merge(admissions,df,how='left',on=['SUBJECT_ID','HADM_ID','ICUSTAY_ID'])
    a=pd.to_datetime(admissions[ids + '_T'])-pd.to_datetime(admissions.INTIME)
    admissions[ids + '_T']=np.round(a.dt.total_seconds()/86400, 2)
    cur.close()
    connex.close()
    return admissions

# %%
admissions=get_pd(database_file, database_loc, ids, admissions)
# Out:
# String of SQL: SELECT * FROM CHARTEVENTS_DB WHERE ITEMID IN (227456);

# %% [markdown]
# ## BUN extraction

# %%
ids = items.ITEMID[3]
admissions=get_pd(database_file, database_loc, ids, admissions)
# Out:
# String of SQL: SELECT * FROM CHARTEVENTS_DB WHERE ITEMID IN (225624);

# %% [markdown]
# ## Creatinine extraction

# %%
ids = items.ITEMID[4]
admissions=get_pd(database_file, database_loc, ids, admissions)
# Out:
# String of SQL: SELECT * FROM CHARTEVENTS_DB WHERE ITEMID IN (220615);

# %% [markdown]
# ## Direct Bilirubin through the remaining features in the order of feature selection in items dataframe

# %%
ids = items.ITEMID[5]
admissions=get_pd(database_file, database_loc, ids, admissions)
# Out:
# String of SQL: SELECT * FROM CHARTEVENTS_DB WHERE ITEMID IN (225651);

# %%
ids = items.ITEMID[6]
admissions=get_pd(database_file, database_loc, ids, admissions)
# Out:
# String of SQL: SELECT * FROM CHARTEVENTS_DB WHERE ITEMID IN (220621);

# %%
ids = items.ITEMID[7]
admissions=get_pd(database_file, database_loc, ids, admissions)
# Out:
# String of SQL: SELECT * FROM CHARTEVENTS_DB WHERE ITEMID IN (226537);

# %%
ids = items.ITEMID[8]
admissions=get_pd(database_file, database_loc, ids, admissions)
# Out:
# String of SQL: SELECT * FROM CHARTEVENTS_DB WHERE ITEMID IN (228388);

# %%
ids = items.ITEMID[9]
admissions=get_pd(database_file, database_loc, ids, admissions)
# Out:
# String of SQL: SELECT * FROM CHARTEVENTS_DB WHERE ITEMID IN (225664);

# %%
ids = items.ITEMID[10]
admissions=get_pd(database_file, database_loc, ids, admissions)
# Out:
# String of SQL: SELECT * FROM CHARTEVENTS_DB WHERE ITEMID IN (220545);

# %%
ids = items.ITEMID[11]
admissions=get_pd(database_file, database_loc, ids, admissions)
# Out:
# String of SQL: SELECT * FROM CHARTEVENTS_DB WHERE ITEMID IN (226540);

# %%
ids = items.ITEMID[12]
admissions=get_pd(database_file, database_loc, ids, admissions)
# Out:
# String of SQL: SELECT * FROM CHARTEVENTS_DB WHERE ITEMID IN (225668);

# %%
ids = items.ITEMID[13]
admissions=get_pd(database_file, database_loc, ids, admissions)
# Out:
# String of SQL: SELECT * FROM CHARTEVENTS_DB WHERE ITEMID IN (220235);

# %%
ids = items.ITEMID[14]
admissions=get_pd(database_file, database_loc, ids, admissions)
# Out:
# String of SQL: SELECT * FROM CHARTEVENTS_DB WHERE ITEMID IN (226062);

# %%
ids = items.ITEMID[15]
admissions=get_pd(database_file, database_loc, ids, admissions)
# Out:
# String of SQL: SELECT * FROM CHARTEVENTS_DB WHERE ITEMID IN (223830);

# %%
ids = items.ITEMID[16]
admissions=get_pd(database_file, database_loc, ids, admissions)
# Out:
# String of SQL: SELECT * FROM CHARTEVENTS_DB WHERE ITEMID IN (220734);

# %%
ids = items.ITEMID[17]
admissions=get_pd(database_file, database_loc, ids, admissions)
# Out:
# String of SQL: SELECT * FROM CHARTEVENTS_DB WHERE ITEMID IN (228243);

# %%
ids = items.ITEMID[18]
admissions=get_pd(database_file, database_loc, ids, admissions)
# Out:
# String of SQL: SELECT * FROM CHARTEVENTS_DB WHERE ITEMID IN (220274);

# %%
ids = items.ITEMID[19]
admissions=get_pd(database_file, database_loc, ids, admissions)
# Out:
# String of SQL: SELECT * FROM CHARTEVENTS_DB WHERE ITEMID IN (227457);

# %%
ids = items.ITEMID[20]
admissions=get_pd(database_file, database_loc, ids, admissions)
# Out:
# String of SQL: SELECT * FROM CHARTEVENTS_DB WHERE ITEMID IN (220224);

# %%
ids = items.ITEMID[21]
admissions=get_pd(database_file, database_loc, ids, admissions)
# Out:
# String of SQL: SELECT * FROM CHARTEVENTS_DB WHERE ITEMID IN (227516);

# %%
ids = items.ITEMID[22]
admissions=get_pd(database_file, database_loc, ids, admissions)
# Out:
# String of SQL: SELECT * FROM CHARTEVENTS_DB WHERE ITEMID IN (226063);

# %%
ids = items.ITEMID[23]
admissions=get_pd(database_file, database_loc, ids, admissions)
# Out:
# String of SQL: SELECT * FROM CHARTEVENTS_DB WHERE ITEMID IN (220227);

# %%
ids = items.ITEMID[24]
admissions=get_pd(database_file, database_loc, ids, admissions)
# Out:
# String of SQL: SELECT * FROM CHARTEVENTS_DB WHERE ITEMID IN (220645);

# %%
ids = items.ITEMID[25]
admissions=get_pd(database_file, database_loc, ids, admissions)
# Out:
# String of SQL: SELECT * FROM CHARTEVENTS_DB WHERE ITEMID IN (228389);

# %%
ids = items.ITEMID[26]
admissions=get_pd(database_file, database_loc, ids, admissions)
# Out:
# String of SQL: SELECT * FROM CHARTEVENTS_DB WHERE ITEMID IN (226534);

# %%
ids = items.ITEMID[27]
admissions=get_pd(database_file, database_loc, ids, admissions)
# Out:
# String of SQL: SELECT * FROM CHARTEVENTS_DB WHERE ITEMID IN (228390);

# %%
ids = items.ITEMID[28]
admissions=get_pd(database_file, database_loc, ids, admissions)
# Out:
# String of SQL: SELECT * FROM CHARTEVENTS_DB WHERE ITEMID IN (225690);

# %%
ids = items.ITEMID[29]
admissions=get_pd(database_file, database_loc, ids, admissions)
# Out:
# String of SQL: SELECT * FROM CHARTEVENTS_DB WHERE ITEMID IN (220546);

# %%
ids = items.ITEMID[30]
admissions=get_pd(database_file, database_loc, ids, admissions)
# Out:
# String of SQL: SELECT * FROM CHARTEVENTS_DB WHERE ITEMID IN (220574);

# %%
ids = items.ITEMID[31]
admissions=get_pd(database_file, database_loc, ids, admissions)
# Out:
# String of SQL: SELECT * FROM CHARTEVENTS_DB WHERE ITEMID IN (225678);

# %%
ids = items.ITEMID[32]
admissions=get_pd(database_file, database_loc, ids, admissions)
# Out:
# String of SQL: SELECT * FROM CHARTEVENTS_DB WHERE ITEMID IN (220739);

# %%
ids = items.ITEMID[33]
admissions=get_pd(database_file, database_loc, ids, admissions)
# Out:
# String of SQL: SELECT * FROM CHARTEVENTS_DB WHERE ITEMID IN (223901);

# %%
ids = items.ITEMID[34]
admissions=get_pd(database_file, database_loc, ids, admissions)
# Out:
# String of SQL: SELECT * FROM CHARTEVENTS_DB WHERE ITEMID IN (223900);

# %%
print(admissions.shape)
print('unique SUBJECT_ID:', admissions.SUBJECT_ID.nunique())
print('unique HADM_ID   :', admissions.HADM_ID.nunique())
print('unique ICUSTAY_ID:', admissions.ICUSTAY_ID.nunique())
admissions.head()
# Out:
# (51518, 125)
# unique SUBJECT_ID: 37778
# unique HADM_ID   : 48372
# unique ICUSTAY_ID: 51518
#    SUBJECT_ID  HADM_ID  ICUSTAY_ID GENDER  AGE_AD            ADMITTIME  \
# 0           3   145834      211552      M   76.53  2101-10-20 19:08:00
# 1           4   185777      294638      F   47.84  2191-03-16 00:28:00
# 2           6   107064      228232      F   65.94  2175-05-30 07:15:00
# 3           9   150750      220597      M   41.79  2149-11-09 13:06:00
# 4          11   194540      229441      F   50.15  2178-04-16 06:18:00
#
#              DISCHTIME ADMISSION_TYPE INSURANCE ETHNICITY  \
# 0  2101-10-31 13:58:00      EMERGENCY  Medicare     WHITE
# 1  2191-03-23 18:41:00      EMERGENCY   Private     WHITE
# 2  2175-06-15 16:00:00       ELECTIVE  Medicare     WHITE
# 3  2149-11-14 10:15:00      EMERGENCY  Medicaid        NW
# 4  2178-05-11 19:00:00      EMERGENCY   Private     WHITE
#
#                              DIAGNOSIS DBSOURCE FIRST_CAREUNIT  FIRST_WARDID  \
# 0                          HYPOTENSION  carevue           MICU            12
# 1  FEVER,DEHYDRATION,FAILURE TO THRIVE  carevue           MICU            52
# 2            CHRONIC RENAL FAILURE/SDA  carevue           SICU            33
# 3                      HEMORRHAGIC CVA  carevue           MICU            15
# 4                           BRAIN MASS  carevue           SICU            57
#
#                 INTIME              OUTTIME     LOS LOS_C  TIMEDELTA  \
# 0  2101-10-20 19:10:11  2101-10-26 20:43:09  6.0646    >4      10.78
# 1  2191-03-16 00:29:31  2191-03-17 16:46:31  1.6785   1-2       7.76
# 2  2175-05-30 21:30:54  2175-06-03 13:39:54  3.6729   2-4      16.36
# 3  2149-11-09 13:07:02  2149-11-14 20:52:14  5.3231    >4       4.88
# 4  2178-04-16 06:19:32  2178-04-17 20:21:05  1.5844   1-2      25.53
#
#   TIMEDELTA_C  HOSPITAL_EXPIRE_FLAG  HEIGHT  WEIGHT  BMI  I_VEN  NI_VEN  \
# 0         >10                     0     NaN     NaN  NaN      0       0
# 1        6-10                     0     NaN     NaN  NaN      0       0
# 2         >10                     0     NaN     NaN  NaN      0       0
# 3         3-6                     1     NaN     NaN  NaN      0       0
# 4         >10                     0     NaN     NaN  NaN      0       0
#
#    227456_T  227456_V 227456_U  225624_T  225624_V 225624_U  220615_T  \
# 0       NaN       NaN      NaN       NaN       NaN      NaN       NaN
# 1       NaN       NaN      NaN       NaN       NaN      NaN       NaN
# 2       NaN       NaN      NaN       NaN       NaN      NaN       NaN
# 3       NaN       NaN      NaN       NaN       NaN      NaN       NaN
# 4       NaN       NaN      NaN       NaN       NaN      NaN       NaN
#
#    220615_V 220615_U  225651_T  225651_V 225651_U  220621_T  220621_V  \
# 0       NaN      NaN       NaN       NaN      NaN       NaN       NaN
# 1       NaN      NaN       NaN       NaN      NaN       NaN       NaN
# 2       NaN      NaN       NaN       NaN      NaN       NaN       NaN
# 3       NaN      NaN       NaN       NaN      NaN       NaN       NaN
# 4       NaN      NaN       NaN       NaN      NaN       NaN       NaN
#
#   220621_U  226537_T  226537_V 226537_U  228388_T 228388_V 228388_U  225664_T  \
# 0      NaN       NaN       NaN      NaN       NaN      NaN      NaN       NaN
# 1      NaN       NaN       NaN      NaN       NaN      NaN      NaN       NaN
# 2      NaN       NaN       NaN      NaN       NaN      NaN      NaN       NaN
# 3      NaN       NaN       NaN      NaN       NaN      NaN      NaN       NaN
# 4      NaN       NaN       NaN      NaN       NaN      NaN      NaN       NaN
#
#    225664_V 225664_U  220545_T  220545_V 220545_U  226540_T  226540_V  \
# 0       NaN      NaN       NaN       NaN      NaN       NaN       NaN
# 1       NaN      NaN       NaN       NaN      NaN       NaN       NaN
# 2       NaN      NaN       NaN       NaN      NaN       NaN       NaN
# 3       NaN      NaN       NaN       NaN      NaN       NaN       NaN
# 4       NaN      NaN       NaN       NaN      NaN       NaN       NaN
#
#   226540_U  225668_T  225668_V 225668_U  220235_T  220235_V 220235_U  \
# 0      NaN       NaN       NaN      NaN       NaN       NaN      NaN
# 1      NaN       NaN       NaN      NaN       NaN       NaN      NaN
# 2      NaN       NaN       NaN      NaN       NaN       NaN      NaN
# 3      NaN       NaN       NaN      NaN       NaN       NaN      NaN
# 4      NaN       NaN       NaN      NaN       NaN       NaN      NaN
#
#    226062_T  226062_V 226062_U  223830_T  223830_V 223830_U  220734_T  \
# 0       NaN       NaN      NaN       NaN       NaN      NaN       NaN
# 1       NaN       NaN      NaN       NaN       NaN      NaN       NaN
# 2       NaN       NaN      NaN       NaN       NaN      NaN       NaN
# 3       NaN       NaN      NaN       NaN       NaN      NaN       NaN
# 4       NaN       NaN      NaN       NaN       NaN      NaN       NaN
#
#    220734_V 220734_U  228243_T 228243_V 228243_U  220274_T  220274_V 220274_U  \
# 0       NaN      NaN       NaN      NaN      NaN       NaN       NaN      NaN
# 1       NaN      NaN       NaN      NaN      NaN       NaN       NaN      NaN
# 2       NaN      NaN       NaN      NaN      NaN       NaN       NaN      NaN
# 3       NaN      NaN       NaN      NaN      NaN       NaN       NaN      NaN
# 4       NaN      NaN       NaN      NaN      NaN       NaN       NaN      NaN
#
#    227457_T  227457_V 227457_U  220224_T  220224_V 220224_U  227516_T  \
# 0       NaN       NaN      NaN       NaN       NaN      NaN       NaN
# 1       NaN       NaN      NaN       NaN       NaN      NaN       NaN
# 2       NaN       NaN      NaN       NaN       NaN      NaN       NaN
# 3       NaN       NaN      NaN       NaN       NaN      NaN       NaN
# 4       NaN       NaN      NaN       NaN       NaN      NaN       NaN
#
#    227516_V 227516_U  226063_T  226063_V 226063_U  220227_T  220227_V  \
# 0       NaN      NaN       NaN       NaN      NaN       NaN       NaN
# 1       NaN      NaN       NaN       NaN      NaN       NaN       NaN
# 2       NaN      NaN       NaN       NaN      NaN       NaN       NaN
# 3       NaN      NaN       NaN       NaN      NaN       NaN       NaN
# 4       NaN      NaN       NaN       NaN      NaN       NaN       NaN
#
#   220227_U  220645_T  220645_V 220645_U  228389_T 228389_V 228389_U  226534_T  \
# 0      NaN       NaN       NaN      NaN       NaN      NaN      NaN       NaN
# 1      NaN       NaN       NaN      NaN       NaN      NaN      NaN       NaN
# 2      NaN       NaN       NaN      NaN       NaN      NaN      NaN       NaN
# 3      NaN       NaN       NaN      NaN       NaN      NaN      NaN       NaN
# 4      NaN       NaN       NaN      NaN       NaN      NaN      NaN       NaN
#
#    226534_V 226534_U  228390_T 228390_V 228390_U  225690_T  225690_V 225690_U  \
# 0       NaN      NaN       NaN      NaN      NaN       NaN       NaN      NaN
# 1       NaN      NaN       NaN      NaN      NaN       NaN       NaN      NaN
# 2       NaN      NaN       NaN      NaN      NaN       NaN       NaN      NaN
# 3       NaN      NaN       NaN      NaN      NaN       NaN       NaN      NaN
# 4       NaN      NaN       NaN      NaN      NaN       NaN       NaN      NaN
#
#    220546_T  220546_V 220546_U  220574_T 220574_V 220574_U  225678_T 225678_V  \
# 0       NaN       NaN      NaN       NaN      NaN      NaN       NaN      NaN
# 1       NaN       NaN      NaN       NaN      NaN      NaN       NaN      NaN
# 2       NaN       NaN      NaN       NaN      NaN      NaN       NaN      NaN
# 3       NaN       NaN      NaN       NaN      NaN      NaN       NaN      NaN
# 4       NaN       NaN      NaN       NaN      NaN      NaN       NaN      NaN
#
#   225678_U  220739_T 220739_V 220739_U  223901_T 223901_V 223901_U  223900_T  \
# 0      NaN       NaN      NaN      NaN       NaN      NaN      NaN       NaN
# 1      NaN       NaN      NaN      NaN       NaN      NaN      NaN       NaN
# 2      NaN       NaN      NaN      NaN       NaN      NaN      NaN       NaN
# 3      NaN       NaN      NaN      NaN       NaN      NaN      NaN       NaN
# 4      NaN       NaN      NaN      NaN       NaN      NaN      NaN       NaN
#
#   223900_V 223900_U
# 0      NaN      NaN
# 1      NaN      NaN
# 2      NaN      NaN
# 3      NaN      NaN
# 4      NaN      NaN

# %%
admissions.to_csv('MAIN_DF_4.csv')
